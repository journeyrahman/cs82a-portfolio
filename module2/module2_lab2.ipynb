# %%
a, b, c = 0, 0, 8
while (b <= c):
    b = b + 1
    print (a)
    a += 5
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40

# %%
def multwhile(c):
    a, b = 0, 0
    while (b <= c):
        b = b + 1
        print (a)
        a += 5

multwhile(8)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40

# %%
print(5 * 8)
# Out:
# 40

# %%
multwhile(6)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30

# %%
print(5 * 6)
# Out:
# 30

# %% [markdown]
# The while loop terminates after the instruction to "add 5 to a" (a += 5) iterates 8 times. This is because b exists solely as a counter for how many times the loop iterates, and the function allows us to modify the number of iterations as desired by plugging in different values for c.
#
# I would like to provide credit to GeeksForGeeks.org for modeling how to embed a counter that iterates:
# https://www.geeksforgeeks.org/python/loops-in-python/

# %%
times_tables = [0]
n = 8
for i in range (0, n):
    times_tables.append(5)
print(times_tables)
print(sum(times_tables))
# Out:
# [0, 5, 5, 5, 5, 5, 5, 5, 5]
# 40

# %%
def multfor(n):
    times_tables = [0]
    for i in range (0, n):
        times_tables.append(5)
    print(times_tables)
    print(sum(times_tables))

multfor(8)
# Out:
# [0, 5, 5, 5, 5, 5, 5, 5, 5]
# 40

# %%
print(5 * 8)
# Out:
# 40

# %%
multfor(6)
# Out:
# [0, 5, 5, 5, 5, 5, 5]
# 30

# %%
print(5 * 6)
# Out:
# 30

# %% [markdown]
# Github Repo Url: https://github.com/journeyrahman/cs82a-portfolio
